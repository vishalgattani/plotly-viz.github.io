# %%
import random
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import sys
from matplotlib.patches import Rectangle
import glob
from _plotly_future_ import v4_subplots
import plotly
import plotly.io as pio
import numpy as np
import chart_studio
import chart_studio.plotly as cspy
import chart_studio.tools as tls
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px

username = 'vishalgattani' # your username\n",
api_key = 'WSy2EFPTbxYYm3Rmcx53' # your api key - go to profile > settings > regenerate key\n",
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
files = []
for file in glob.glob("../datasets/earthquake*"):
    files.append(file)

# %%
main = pd.read_csv(files[0])
curr = pd.read_csv(files[1])

# %%
main.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
main.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2022-03-04T21:28:02.440Z  38.759666 -122.719666   1.61  1.24      md  14.0
# 1  2022-03-04T21:27:28.190Z  38.833832 -122.815498   1.82  1.13      md  22.0
# 2  2022-03-04T21:25:05.130Z  35.596668 -120.271332  11.57  2.31      md   5.0
# 3  2022-03-04T21:20:43.590Z  35.929167 -117.660833   3.25  0.88      ml   9.0
# 4  2022-03-04T21:19:08.215Z  62.360200 -149.634500   9.80  1.40      ml   NaN
#
#      gap      dmin   rms net            id                   updated  \
# 0  115.0  0.004494  0.04  nc    nc73701241  2022-03-04T21:29:36.906Z
# 1   66.0  0.016320  0.02  nc    nc73701236  2022-03-04T21:29:02.128Z
# 2  178.0  0.159000  0.01  nc    nc73701231  2022-03-04T21:26:56.893Z
# 3   73.0  0.020530  0.13  ci    ci40199696  2022-03-04T21:24:10.449Z
# 4    NaN       NaN  0.52  ak  ak0222wjh21x  2022-03-04T21:22:15.794Z
#
#                                 place        type  horizontalError  \
# 0      3km SW of Anderson Springs, CA  earthquake             0.30
# 1           8km NW of The Geysers, CA  earthquake             0.19
# 2              11km SE of Shandon, CA  earthquake             3.14
# 3           22km E of Little Lake, CA  earthquake             0.33
# 4  24 km NNE of Susitna North, Alaska  earthquake              NaN
#
#    depthError  magError  magNst     status locationSource magSource
# 0        0.36     0.100     5.0  automatic             nc        nc
# 1        0.53     0.140     4.0  automatic             nc        nc
# 2        3.51     0.760     3.0  automatic             nc        nc
# 3        0.74     0.055    10.0  automatic             ci        ci
# 4        0.50       NaN     NaN  automatic             ak        ak
